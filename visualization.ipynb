# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
y = [0,0,0,0,0,]

# %%
plt.plot(y)

# %%
madhav = [99,88,77,66,55]
bharghav = [99,88,77,66,55]
sameer = [99,88,77,66,55]

# %%
plt.plot(madhav)
plt.plot(bharghav)
plt.plot(sameer)

# %%
madhav = [99,98,97,96,95]
sameer = [94,93,92,91,90]
bhargav = [89,88,87,86,85]

# %%
plt.plot(sameer,'r',label = "sameer",marker = "o")
plt.plot(bhargav,'g',label = "bhargav",marker = "*")
plt.plot(madhav,'b',label = "madhav",marker = "+")
plt.legend()

# %%
temperature = [35.5,36.8,46.8,32.3,43.4,35.6,43.4]
days = ["monday","tuesday","wednesday","thursday","friend","saterday","sunday"]
plt.bar(days, height= temperature)
# Out:
# <BarContainer object of 7 artists>

# %%
sports = [11,7,6,4,2]
names = ["Cricket","Kabbadi","VolleyBall","Carroms","Chess"]
colors = ['lavender','pink','black','yellow','red']

# %%
plt.pie(sports,labels=names,colors=colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x221b8aa7d90>,
# ...
#  [Text(0.447410275171291, 1.0049000177486065, 'Cricket'),
#   Text(-1.0939741083288377, 0.11498108673222909, 'Kabbadi'),
#   Text(-0.33991831634615544, -1.046162290570825, 'VolleyBall'),
#   Text(0.7360437908666487, -0.8174591964903528, 'Carroms'),
#   Text(1.0759624539888648, -0.2287024215137656, 'Chess')])

# %%
data = [100000,12000,29919,19000,25000]
players = ['madhav','sameer','bhargav','yaswanth','bhuvan']
plt.barh(players,data)
# Out:
# <BarContainer object of 5 artists>

# %%
data = [100000,12000,29919,19000,25000]
players = ['madhav','sameer','bhargav','yaswanth','bhuvan']
fig,ax = plt.subplots(figsize=(10,5))
plt.barh(players,data)
# Out:
# <BarContainer object of 5 artists>
